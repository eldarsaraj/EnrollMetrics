# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
all = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/all.csv')
all = all[['Semester', '# of Sections', '# Enrolled']]
all
# Out:
#    Semester  # of Sections  # Enrolled
# 0     2003s          109.0      2675.0
# 1     2003f          116.0      2909.0
# 2     2004s          104.0      2507.0
# 3     2004f          104.0      2533.0
# 4     2005s          100.0      2358.0
# 5     2005f          100.0      2329.0
# 6     2006s           94.0      2286.0
# 7     2006f          112.0      2666.0
# 8     2007s          103.0      2243.0
# 9     2007f          113.0      2747.0
# 10    2008s          112.0      2719.0
# 11    2008f          132.0      3399.0
# 12    2009f          134.0      3133.0
# 13    2010s          153.0      3622.0
# 14    2010f          157.0      3976.0
# 15    2011s          163.0      3912.0
# 16    2011f          177.0      4395.0
# 17    2012s          176.0      4176.0
# 18    2012f          175.0      4205.0
# 19    2013s          172.0      3914.0
# 20    2013f          187.0      4056.0
# 21    2014s          173.0      4002.0
# 22    2014f          197.0      5154.0
# ...

# %% [markdown]
# ## FALL 2021

# %%
fall_21 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_21.csv')

CRT_21f = fall_21[fall_21.Course.str.contains('CRT', case=False)]
ACR_21f = fall_21[fall_21.Course.str.contains('ACR', case=False)]
ESL_21f = fall_21[fall_21.Course.str.contains('ESL', case=False)]
LIN_21f = fall_21[fall_21.Course.str.contains('LIN', case=False)]
ACL_21f = fall_21[fall_21.Course.str.contains('ACL', case=False)]
Pre_Col_21f = fall_21[fall_21.Course.str.contains('College', case=False)]

data21f = {'Course Group': ['ACL', 'CRT', 'ESL', 'LIN' ], 
        '# of Sections': [ACR_21f['# of Sections'].sum(), CRT_21f['# of Sections'].sum(),
                         ESL_21f['# of Sections'].sum(), LIN_21f['# of Sections'].sum()],
       '# Enrolled': [ACR_21f['# Enrolled'].sum(), CRT_21f['# Enrolled'].sum(),
                         ESL_21f['# Enrolled'].sum(), LIN_21f['# Enrolled'].sum()]}



all_21f = pd.DataFrame(data21f)

all_21f
all_21f
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             22         459
# 1          CRT             53         867
# 2          ESL             19         248
# 3          LIN             39         670

# %% [markdown]
# # SPRING 2021

# %%
spring_21 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_21.csv')

CRT_21s = spring_21[spring_21.Course.str.contains('CRT', case=False)]
ACR_21s = spring_21[spring_21.Course.str.contains('ACR', case=False)]
ESL_21s = spring_21[spring_21.Course.str.contains('ESL', case=False)]
LIN_21s = spring_21[spring_21.Course.str.contains('LIN', case=False)]
ACL_21s = spring_21[spring_21.Course.str.contains('ACL', case=False)]

data21s = {'Course Group': ['ACL', 'CRT', 'ESL', 'LIN' ], 
        '# of Sections': [ACR_21s['# of Sections'].sum(), CRT_21s['# of Sections'].sum(),
                         ESL_21s['# of Sections'].sum(), LIN_21s['# of Sections'].sum()],
       '# Enrolled': [ACR_21s['# Enrolled'].sum(), CRT_21s['# Enrolled'].sum(),
                         ESL_21s['# Enrolled'].sum(), LIN_21s['# Enrolled'].sum()]}

all_21s = pd.DataFrame(data21s)

all_21s
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             12         245
# 1          CRT             52         919
# 2          ESL             13         195
# 3          LIN             36         703

# %% [markdown]
# # FALL 2022

# %%
fall_22 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_22.csv')

CRT_22f = fall_22[fall_22.Course.str.contains('CRT', case=False)]
ACR_22f = fall_22[fall_22.Course.str.contains('ACR', case=False)]
ESL_22f = fall_22[fall_22.Course.str.contains('ESL', case=False)]
LIN_22f = fall_22[fall_22.Course.str.contains('LIN', case=False)]
ACL_22f = fall_22[fall_22.Course.str.contains('ACL', case=False)]
Pre_Col_22f = fall_22[fall_22.Course.str.contains('College', case=False)]

data22f = {'Course Group': ['ACL', 'CRT', 'ESL', 'LIN' ], 
        '# of Sections': [ACR_22f['# of Sections'].sum(), CRT_22f['# of Sections'].sum(),
                         ESL_22f['# of Sections'].sum(), LIN_22f['# of Sections'].sum()],
       '# Enrolled': [ACR_22f['# Enrolled'].sum(), CRT_22f['# Enrolled'].sum(),
                         ESL_22f['# Enrolled'].sum(), LIN_22f['# Enrolled'].sum()]}

all_22f = pd.DataFrame(data22f)

all_22f
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             25         436
# 1          CRT             53         660
# 2          ESL             24         409
# 3          LIN             43         558

# %% [markdown]
# # SPRING 2022

# %%
spring_22 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_22.csv')

CRT_22s = spring_22[spring_22.Course.str.contains('CRT', case=False)]
ACR_22s = spring_22[spring_22.Course.str.contains('ACR', case=False)]
ESL_22s = spring_22[spring_22.Course.str.contains('ESL', case=False)]
LIN_22s = spring_22[spring_22.Course.str.contains('LIN', case=False)]
ACL_22s = spring_22[spring_22.Course.str.contains('ACL', case=False)]
Pre_Cols_22s = spring_22[spring_22.Course.str.contains('College', case=False)]

data22s = {'Course Group': ['ACL', 'CRT', 'ESL', 'LIN' ], 
        '# of Sections': [ACR_22s['# of Sections'].sum(), CRT_22s['# of Sections'].sum(),
                         ESL_22s['# of Sections'].sum(), LIN_22s['# of Sections'].sum()],
       '# Enrolled': [ACR_22s['# Enrolled'].sum(), CRT_22s['# Enrolled'].sum(),
                         ESL_22s['# Enrolled'].sum(), LIN_22s['# Enrolled'].sum()]}



all_22s = pd.DataFrame(data22s)

all_22s
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             20         384
# 1          CRT             54         931
# 2          ESL             16         190
# 3          LIN             39         632

# %% [markdown]
# # SPRING 2023

# %%
spring_23 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_23.csv')

spring_23.columns = ['Course', '# of Sections', '# Enrolled']

CRT_23s = spring_23[spring_23.Course.str.contains('CRT', case=False)]
ACR_23s = spring_23[spring_23.Course.str.contains('ACR', case=False)]
ESL_23s = spring_23[spring_23.Course.str.contains('ESL', case=False)]
LIN_23s = spring_23[spring_23.Course.str.contains('LIN', case=False)]
ACL_23s = spring_23[spring_23.Course.str.contains('ACL', case=False)]
Pre_Cols_23s = spring_23[spring_23.Course.str.contains('College', case=False)]

data23s = {'Course Group': ['ACL', 'CRT', 'ESL', 'LIN' ], 
        '# of Sections': [ACL_23s['# of Sections'].sum(), CRT_23s['# of Sections'].sum(),
                         ESL_23s['# of Sections'].sum(), LIN_23s['# of Sections'].sum()],
       '# Enrolled': [ACL_23s['# Enrolled'].sum(), CRT_23s['# Enrolled'].sum(),
                         ESL_23s['# Enrolled'].sum(), LIN_23s['# Enrolled'].sum()]}



all_23s = pd.DataFrame(data23s)

all_23s
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             11         105
# 1          CRT             60         760
# 2          ESL             25         343
# 3          LIN             36         424

# %%
all_23s
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             11         105
# 1          CRT             60         760
# 2          ESL             25         343
# 3          LIN             36         424

# %%
x = np.arange(len(all_23s[['# Enrolled']])) 
fig, ax = plt.subplots(figsize=(9,5))
ax.bar(x, all_23s['# Enrolled'])
ax.set_xticks(x, all_23s['Course Group'])

# %%
selected_course = st.selectbox('What course would you like to compare to Spring 2022?', ['ACL', 'CRT', 'ESL', 'LIN'])
                                
            fig, ax = plt.subplots(figsize=(10,7))
            x = np.arange(1) 
            ax.bar(x-0.02, (all_22s[all_22s['Course Group'].str.contains(str(selected_course))]['# Enrolled']), width=0.03, color='#415d43')
            ax.bar(x+0.02, (all_23s[all_23s['Course Group'].str.contains(str(selected_course))]['# Enrolled']), width=0.03, color='#709775')
            ax.legend(['Spring 22', 'Spring 23'])
            #ax.grid(alpha=0.2)
            
            ax.spines['top'].set_visible(False)
            ax.spines['bottom'].set_visible(False)
            ax.spines['left'].set_visible(False)
            ax.spines['right'].set_visible(False)
                
            plt.title('{} in Spring 2022 and 2023'.format(selected_course))
                
            ax.set_xticks(x)
            
                
            st.pyplot(fig)
# Out:
#                # of Sections  # Enrolled
# Course
# Regular Total             97        1331
# ACL 150                    3          40
# ACL 195                    1          20
# ACL 200                    2          24
# CRT 100                   30         378
# CRT 100.6                  4          61
# CRT 100H                   1          25
# CRT 120                    3          34
# CRT 150                    3          49
# CRT 196                    1          17
# ESL  49                    1          20
# ESL  54                    1          20
# ESL  94RW                  5          94
# ESL  96                   14         191
# LIN 100                    3          41
# LIN 101                    3          37
# LIN 110                    1          23
# LIN 140                    1           8
# LIN 150                    7         102
# LIN 150H                   1           3
# LIN 210                    1          10
# LIN 250                   10         131
# ...

# %%
ACL_23s.sort_values(by=['# Enrolled'], ascending=False)
# Out:
#      Course  # of Sections  # Enrolled
# 1   ACL 150              3          40
# 3   ACL 200              2          24
# 2   ACL 195              1          20
# 24  ACL 150              1          13
# 29  ACL 120              1           3
# 31  ACL 200              1           3
# 28  ACL 110              1           2
# 30  ACL 150              1           0

# %%
ACL_23s['Course'].unique()
# Out:
# array(['ACL 150', 'ACL 195', 'ACL 200', 'ACL 110', 'ACL 120'],
#       dtype=object)

# %%
import altair as alt

# %%
data = pd.DataFrame({'a': list('CCCDDDEEE'),
                     'b': [2, 7, 4, 1, 2, 6, 8, 4, 7]})

chart = alt.Chart(data)

alt.Chart(data).mark_bar(color='#a1cca5').encode(
    alt.Y('a', title='Category'), 
    alt.X('average(b)', title='avg(b) by category')
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(all_21f).mark_bar(color='#a1cca5').encode(
    y='# Enrolled', x='Course Group', color='Course Group')
# Out:
# alt.Chart(...)

# %%
all_23s
# Out:
#   Course Group  # of Sections  # Enrolled
# 0          ACL             11         105
# 1          CRT             60         760
# 2          ESL             25         343
# 3          LIN             36         424

# %%
4*('Fall 2021')
# Out:
# 'Fall 2021Fall 2021Fall 2021Fall 2021'

# %%
stacked = pd.concat([all_21s, all_21f, all_22s, all_22f, all_23s], axis=0)
stacked['Semester'] = ['Spring 2021', 'Spring 2021','Spring 2021', 'Spring 2021',
                       'Fall 2021', 'Fall 2021', 'Fall 2021', 'Fall 2021',
                       'Spring 2022', 'Spring 2022', 'Spring 2022', 'Spring 2022',
                        'Fall 2022', 'Fall 2022', 'Fall 2022', 'Fall 2022', 
                        'Spring 2023', 'Spring 2023', 'Spring 2023', 'Spring 2023',
]
#stacked = stacked.set_index('Semester')
stacked
# Out:
#   Course Group  # of Sections  # Enrolled     Semester
# 0          ACL             12         245  Spring 2021
# 1          CRT             52         919  Spring 2021
# 2          ESL             13         195  Spring 2021
# 3          LIN             36         703  Spring 2021
# 0          ACL             22         459    Fall 2021
# 1          CRT             53         867    Fall 2021
# 2          ESL             19         248    Fall 2021
# 3          LIN             39         670    Fall 2021
# 0          ACL             20         384  Spring 2022
# 1          CRT             54         931  Spring 2022
# 2          ESL             16         190  Spring 2022
# 3          LIN             39         632  Spring 2022
# 0          ACL             25         436    Fall 2022
# 1          CRT             53         660    Fall 2022
# 2          ESL             24         409    Fall 2022
# 3          LIN             43         558    Fall 2022
# ...

# %%
alt.Chart(stacked).mark_bar().encode(
    y='# Enrolled', x='Course Group', color='Course Group', column='Semester')
# Out:
# alt.Chart(...)

# %%
class DataFramer:
    
    def __init__(self, name, df):
        self.name = name
        self.df = df
        
    def get_name(self):
        print(self.name)
    
    def get_df(self):
        return self.df
    
    def get_ACL(self):  
        self.ACL = self.df[self.df.Course.str.contains('ACL', case=False)].groupby('Course').first().reset_index()
        return self.ACL
    
    def get_RDG(self):
        self.RDG = self.df[self.df.Course.str.contains('RDG', case=False)].groupby('Course').first().reset_index()
        return self.RDG
    
    def get_ACR(self):
        self.ACR = self.df[self.df.Course.str.contains('ACR', case=False)].groupby('Course').first().reset_index()
        return self.ACR
    
    def get_CRT(self):
        self.CRT = self.df[self.df.Course.str.contains('CRT', case=False)].groupby('Course').first().reset_index()
        return self.CRT
    
    def get_ESL(self):
        self.ESL = self.df[self.df.Course.str.contains('ESL', case=False)].groupby('Course').first().reset_index()
        return self.ESL
    
    def get_LIN(self):
        self.LIN = self.df[self.df.Course.str.contains('LIN', case=False)].groupby('Course').first().reset_index()
        return self.LIN

# %%
spring_03 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2003.csv')
fall_03 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2003.csv')
spring_04 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2004.csv')
fall_04 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2004.csv')
spring_05 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2005.csv')
fall_05 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2005.csv')
spring_06 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2006.csv')
fall_06 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2006.csv')
spring_07 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2007.csv')
fall_07 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2007.csv')
spring_08 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2008.csv')
fall_08 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2008.csv')
spring_09 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2009.csv')
fall_09 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2009.csv')
spring_10 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2010.csv')
fall_10 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2010.csv')
spring_11 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2011.csv')
fall_11 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2011.csv')
spring_12 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2012.csv')
fall_12 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2012.csv')
spring_13 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2013.csv')
fall_13 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2013.csv')
spring_14 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2014.csv')
fall_14 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2014.csv')
spring_15 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2015.csv')
fall_15 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2015.csv')
spring_16 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_2016.csv')
fall_16 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2016.csv')
spring_17 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_17.csv')
fall_17 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_17.csv')
spring_18 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_18.csv')
fall_18 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_18.csv')
spring_19 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_19.csv')
fall_19 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_19.csv')
spring_20 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_20.csv')
fall_20 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_2020.csv')
spring_21 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_21.csv')
fall_21 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_21.csv')
spring_22 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_22.csv')
fall_22 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_22.csv')
spring_23 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/spring_23.csv')

# %%
class DataFramer:
    
    def __init__(self, name, df):
        self.name = name
        if 'Unnamed: 0' in df.columns:
            self.df = df.drop(columns=['Unnamed: 0'])  # drop the 'Unnamed: 0' column if it exists
        else:
            self.df = df 
        
    def get_name(self):
        print(self.name)
    
    def get_df(self):
        return self.df
    
    def get_ACL(self):  
        self.ACL = self.df[self.df['Course'].str.contains('ACL')].groupby('Course').first().reset_index()
        return self.ACL
    
    def get_ACR(self):  
        self.ACR = self.df[self.df['Course'].str.contains('ACR')].groupby('Course').first().reset_index()
        return self.ACR
    
    def get_CRT(self):  
        self.CRT = self.df[self.df['Course'].str.contains('CRT')].groupby('Course').first().reset_index()
        return self.CRT
    
    def get_ESL(self):  
        self.ESL = self.df[self.df['Course'].str.contains('ESL')].groupby('Course').first().reset_index()
        return self.ESL
    
    def get_LIN(self):  
        self.LIN = self.df[self.df['Course'].str.contains('LIN')].groupby('Course').first().reset_index()
        return self.LIN
    
    def get_RDG(self):  
        self.RDG = self.df[self.df['Course'].str.contains('RDG')].groupby('Course').first().reset_index()
        return self.RDG

# %%
spring_2003 = DataFramer('Spring 2003', spring_03)
spring_2004 = DataFramer('Spring 2004', spring_04)
spring_2005 = DataFramer('Spring 2005', spring_05)
spring_2006 = DataFramer('Spring 2006', spring_06)
spring_2007 = DataFramer('Spring 2007', spring_07)
spring_2008 = DataFramer('Spring 2008', spring_08)
spring_2009 = DataFramer('Spring 2009', spring_09)
spring_2010 = DataFramer('Spring 2010', spring_10)
spring_2011 = DataFramer('Spring 2011', spring_11)
spring_2012 = DataFramer('Spring 2012', spring_12)
spring_2013 = DataFramer('Spring 2013', spring_13)
spring_2014 = DataFramer('Spring 2014', spring_14)
spring_2015 = DataFramer('Spring 2015', spring_15)
spring_2016 = DataFramer('Spring 2016', spring_16)
spring_2017 = DataFramer('Spring 2017', spring_17)
spring_2018 = DataFramer('Spring 2018', spring_18)
spring_2019 = DataFramer('Spring 2019', spring_19)
spring_2020 = DataFramer('Spring 2020', spring_20)
spring_2021 = DataFramer('Spring 2021', spring_21)
spring_2022 = DataFramer('Spring 2022', spring_22)
spring_2023 = DataFramer('Spring 2023', spring_23)

# %%
fall_2003 = DataFramer('Fall 2003', fall_03)
fall_2004 = DataFramer('Fall 2004', fall_04)
fall_2005 = DataFramer('Fall 2005', fall_05)
fall_2006 = DataFramer('Fall 2006', fall_06)
fall_2007 = DataFramer('Fall 2007', fall_07)
fall_2008 = DataFramer('Fall 2008', fall_08)
fall_2009 = DataFramer('Fall 2009', fall_09)
fall_2010 = DataFramer('Fall 2010', fall_10)
fall_2011 = DataFramer('Fall 2011', fall_11)
fall_2012 = DataFramer('Fall 2012', fall_12)
fall_2013 = DataFramer('Fall 2013', fall_13)
fall_2014 = DataFramer('Fall 2014', fall_14)
fall_2015 = DataFramer('Fall 2015', fall_15)
fall_2016 = DataFramer('Fall 2016', fall_16)
fall_2017 = DataFramer('Fall 2017', fall_17)
fall_2018 = DataFramer('Fall 2018', fall_18)
fall_2019 = DataFramer('Fall 2019', fall_19)
fall_2020 = DataFramer('Fall 2020', fall_20)
fall_2021 = DataFramer('Fall 2021', fall_21)
fall_2022 = DataFramer('Fall 2022', fall_22)

# %%
fall_2022.get_CRT()['# Enrolled'].sum()
# Out:
# 494

# %%
fall_2022.get_name()
# Out:
# Fall 2022

# %%
totals_enrolled = pd.DataFrame({'Semester': [spring_2002.get_name(), fall_2002.get_name(),
                                            spring_2003.get_name(), fall_2003.get_name(),
                                            spring_2004.get_name(), fall_2004.get_name(),
                                            spring_2005.get_name(), fall_2005.get_name(),
                                            spring_2005.get_name(), fall_2005.get_name(),
                                            spring_2006.get_name(), fall_2006.get_name(), 
                                            spring_2007.get_name(), fall_2007.get_name(),
                                            spring_2008.get_name(), fall_2008.get_name(),
                                            spring_2009.get_name(), fall_2009.get_name(),
                                            spring_2010.get_name(), fall_2010.get_name(),
                                            spring_2011.get_name(), fall_2011.get_name(),
                                            spring_2012.get_name(), fall_2012.get_name(),
                                            spring_2013.get_name(), fall_2013.get_name(),
                                            spring_2014.get_name(), fall_2014.get_name(),
                                            spring_2015.get_name(), fall_2015.get_name(),
                                            spring_2016.get_name(), fall_2016.get_name(),
                                            spring_2017.get_name(), fall_2017.get_name(),
                                            spring_2018.get_name(), fall_2018.get_name(),
                                            spring_2019.get_name(), fall_2019.get_name(),
                                            spring_2020.get_name(), fall_2020.get_name(),
                                            spring_2021.get_name(), fall_2021.get_name(),
                                            spring_2022.get_name(), fall_2022.get_name(),
                                            spring_2023.get_name()]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[353], line 1
# ----> 1 totals_enrolled = pd.DataFrame({'Fall 2003': fall_2003.get_CRT()['# Enrolled'].sum(),
#       2                                'Fall 2004': fall_2004.get_CRT()['# Enrolled'].sum()})
#       3 totals_enrolled
#
# File ~/Desktop/Documents/Data_Projects/streamlit2/env/lib/python3.10/site-packages/pandas/core/frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
# ...

# %%
fall_22.drop(columns=['Unnamed: 0'])
# Out:
#          Course  # of Sections  # Enrolled
# 0       Regular            107        1614
# 1       ACR 150             12         213
# 2       ACR 195              4          81
# 3       ACR 200              5          82
# 4       CRT 100             29         391
# 5     CRT 100.6              4          34
# 6       CRT 120              1          13
# 7       CRT 150              2          30
# 8       ESL  49              1          23
# 9       ESL  54              1          23
# 10    ESL  94RW              4          73
# 11      ESL  96             11         229
# 12      LIN 100              7          91
# 13     LIN 100H              1           5
# 14      LIN 101              2          35
# 15     LIN 101H              1           6
# 16      LIN 110              1           9
# 17      LIN 130              1          15
# 18      LIN 140              1           7
# 19      LIN 150              7          92
# 20      LIN 200              1           3
# ...

# %%
def class_heatmap(df):
    times = df[df[['Days', 'Mtg Start']].notna().all(axis=1)]
    times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
    times.loc[:, 'Mtg End'] = pd.to_datetime(times['Mtg End'])
    times.loc[:, 'Mtg Start'] = times['Mtg Start'].dt.strftime('%H:%M')
    times.loc[:, 'Mtg End'] = times['Mtg End'].dt.strftime('%H:%M')
    
    day_dict = {
    'M': 'Monday',
    'Tu': 'Tuesday',
    'MW': 'Monday, Wednesday',
    'MTh': 'Monday, Thursday',
    'TuTh': 'Tuesday, Thursday',
    'TuF': 'Tuesday, Friday',
    'MTuWTh': 'Monday, Tuesday, Wednesday, Thursday',
    'MWTh': 'Monday, Wednesday, Thursday',
    'MTuTh': 'Monday, Tuesday, Thursday',
    'TuW': 'Tuesday, Wednesday',
    'W': 'Wednesday',
    'Th': 'Thursday',
    'F': 'Friday',
    'Sa': 'Saturday',
    'Su': 'Sunday'}
    
    def convert_days(days):
        output_days = []
        for day in days.split(','):
            if day.strip() in day_dict:
                output_days.append(day_dict[day.strip()])
        return output_days
    
    times['Day'] = times['Days'].apply(convert_days).apply(', '.join)
    times = times.assign(Day=times.Day.str.split(","))
    times = times.explode('Day')
    
    day_df = times[['Mtg Start', 'Mtg End', 'Day']]
    
    stacked_days = pd.concat([day_df[day_df['Day']=='Monday'], 
                          day_df[day_df['Day']=='Tuesday'], 
                          day_df[day_df['Day']=='Wednesday'], 
                          day_df[day_df['Day']=='Thursday'],
                          day_df[day_df['Day']=='Friday'],
                          day_df[day_df['Day']=='Saturday'],
                          day_df[day_df['Day']=='Sunday']],
                          axis=0)
    stacked_days['Mtg Start'] = stacked_days['Mtg Start'].astype(str)
    stacked_days['Mtg End'] = stacked_days['Mtg End'].astype(str)

    df_pivot = stacked_days.pivot_table(index='Day', columns=['Mtg Start', 'Mtg End'], aggfunc=len, fill_value=0)

    df_pivot_long = df_pivot.reset_index().melt(id_vars=['Day'], var_name=['Mtg Start', 'Mtg End'], value_name='Count')

    chart = alt.Chart(df_pivot_long).mark_rect().encode(
        y=alt.Y('Mtg Start:O', title='Class Start Time'),
        x=alt.X('Day:O', sort=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']),
        color=alt.Color('Count:Q', title='Number of Meetings', scale=alt.Scale(scheme='blues')),
        tooltip=[alt.Tooltip('Count:Q', title='Number of Meetings')]
    ).properties(
        width=600,
        height=300,
        title='Class Meetings Time of the Day'
    )
    chart = chart.configure_axis(labelAngle=-0, title='')
    
    return chart
        
class_heatmap(sp)
# Out:
# /var/folders/6q/ndqjw6ws3jx7kqy618mjsznc0000gn/T/ipykernel_4823/470993907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
# /var/folders/6q/ndqjw6ws3jx7kqy618mjsznc0000gn/T/ipykernel_4823/470993907.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
# /var/folders/6q/ndqjw6ws3jx7kqy618mjsznc0000gn/T/ipykernel_4823/470993907.py:4: SettingWithCopyWarning:
# ...

# %%
list(df_pivot_long['Mtg Start'].unique())
# Out:
# ['07:40:00',
#  '08:00:00',
#  '09:00:00',
#  '10:00:00',
#  '10:30:00',
#  '11:00:00',
#  '12:00:00',
#  '12:30:00',
#  '13:00:00',
#  '13:17:00',
#  '13:45:00',
#  '14:00:00',
#  '14:50:00',
#  '15:00:00',
#  '15:30:00',
#  '16:00:00',
#  '17:00:00',
#  '17:20:00',
#  '17:30:00',
#  '18:00:00',
#  '18:30:00']

# %%
sp = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1)
times = sp[sp[['Days', 'Mtg Start']].notna().all(axis=1)]
times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
times.loc[:, 'Mtg End'] = pd.to_datetime(times['Mtg End'])
times.loc[:, 'Mtg Start'] = times['Mtg Start'].dt.strftime('%H:%M')
times.loc[:, 'Mtg End'] = times['Mtg End'].dt.strftime('%H:%M')

day_dict = {
    'M': 'Monday',
    'Tu': 'Tuesday',
    'MW': 'Monday, Wednesday',
    'MTh': 'Monday, Thursday',
    'TuTh': 'Tuesday, Thursday',
    'TuF': 'Tuesday, Friday',
    'MTuWTh': 'Monday, Tuesday, Wednesday, Thursday',
    'MWTh': 'Monday, Wednesday, Thursday',
    'MTuTh': 'Monday, Tuesday, Thursday',
    'TuW': 'Tuesday, Wednesday',
    'W': 'Wednesday',
    'Th': 'Thursday',
    'F': 'Friday',
    'Sa': 'Saturday',
    'Su': 'Sunday'
}

def convert_days(days):
    output_days = []
    for day in days.split(','):
        if day.strip() in day_dict:
            output_days.append(day_dict[day.strip()])
    return output_days

times['Day'] = times['Days'].apply(convert_days).apply(', '.join)

times = times.assign(Day=times.Day.str.split(","))
times = times.explode('Day')
times
# Out:
# /var/folders/6q/ndqjw6ws3jx7kqy618mjsznc0000gn/T/ipykernel_4823/3189793565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
# /var/folders/6q/ndqjw6ws3jx7kqy618mjsznc0000gn/T/ipykernel_4823/3189793565.py:3: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
# /var/folders/6q/ndqjw6ws3jx7kqy618mjsznc0000gn/T/ipykernel_4823/3189793565.py:4: SettingWithCopyWarning:
# ...

# %%
day_df = times[['Mtg Start', 'Mtg End', 'Day']]
stacked_days = pd.concat([day_df[day_df['Day']=='Monday'], 
                          day_df[day_df['Day']=='Tuesday'], 
                          day_df[day_df['Day']=='Wednesday'], 
                          day_df[day_df['Day']=='Thursday'],
                          day_df[day_df['Day']=='Friday'],
                          day_df[day_df['Day']=='Saturday'],
                          day_df[day_df['Day']=='Sunday']],
                          axis=0)
stacked_days
# Out:
#     Mtg Start   Mtg End       Day
# 8    10:00:00  11:15:00    Monday
# 9    10:00:00  11:15:00    Monday
# 14   15:00:00  16:15:00    Monday
# 67   09:00:00  10:15:00    Monday
# 70   10:30:00  13:15:00    Monday
# ..        ...       ...       ...
# 60   08:00:00  09:40:00    Friday
# 98   17:00:00  19:45:00    Friday
# 211  12:00:00  13:15:00    Friday
# 62   09:00:00  11:45:00  Saturday
# 87   13:00:00  15:45:00  Saturday
#
# [93 rows x 3 columns]

# %%
import altair as alt

stacked_days['Mtg Start'] = stacked_days['Mtg Start'].astype(str)
stacked_days['Mtg End'] = stacked_days['Mtg End'].astype(str)

df_pivot = stacked_days.pivot_table(index='Day', columns=['Mtg Start', 'Mtg End'], aggfunc=len, fill_value=0)

# Convert the pivoted dataframe to long format
df_pivot_long = df_pivot.reset_index().melt(id_vars=['Day'], var_name=['Mtg Start', 'Mtg End'], value_name='Count')

# Create the heatmap using Altair
chart = alt.Chart(df_pivot_long).mark_rect().encode(
    y=alt.Y('Mtg Start:O', title='Class Start Time'),
    x=alt.X('Day:O', sort=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']),
    color=alt.Color('Count:Q', title='Number of Meetings', scale=alt.Scale(scheme='blues')),
    tooltip=[alt.Tooltip('Count:Q', title='Number of Meetings')]
).properties(
    width=600,
    height=300,
    title='Class Meetings Time of the Day'
)
chart = chart.configure_axis(labelAngle=-0, title='')
chart
# Out:
# alt.Chart(...)

# %%
df_pivot_long
# Out:
#            Day Mtg Start   Mtg End  Count
# 0       Friday  07:40:00  08:55:00      0
# 1       Monday  07:40:00  08:55:00      0
# 2     Saturday  07:40:00  08:55:00      0
# 3     Thursday  07:40:00  08:55:00      0
# 4      Tuesday  07:40:00  08:55:00      1
# ..         ...       ...       ...    ...
# 211     Monday  18:30:00  20:15:00      1
# 212   Saturday  18:30:00  20:15:00      0
# 213   Thursday  18:30:00  20:15:00      0
# 214    Tuesday  18:30:00  20:15:00      4
# 215  Wednesday  18:30:00  20:15:00      0
#
# [216 rows x 4 columns]

# %%
status = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1)
status
# Out:
#      Term Class Stat Subject Catalog# Section                     Class Title  \
# 0    1232  Cancelled     ACL      110    0500  Discipl Read in the Humanities
# 1    1232  Cancelled     ACL      110    1800  Discipl Read in the Humanities
# 2    1232  Cancelled     ACL      120    0500     Reading for Justice and Law
# 3    1232  Cancelled     ACL      120    1000     Reading for Justice and Law
# 4    1232     Active     ACL      150    0500    Literacy in American Society
# ..    ...        ...     ...      ...     ...                             ...
# 275  1232  Cancelled     ACL      150    J050    Literacy in American Society
# 276  1232     Active     CRT      100    J050               Critical Thinking
# 277  1232     Active     CRT      100    J051               Critical Thinking
# 278  1232     Active     LIN      100    J050            Language And Culture
# 279  1232     Active     LIN      250    J050            Forensic Linguistics
#
# ...

# %%
status = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1)
status = status[['Class Stat', 'Subject']]
status.columns = ['Status', 'Course Group']
status_pivot = status.pivot_table(index='Status', columns='Course Group', aggfunc=len)
status_pivot.fillna(0, inplace=True)
status_pivot
# Out:
# Course Group   ACL  ACR   CRT   ESL   LIN
# Status
# Active        12.0  0.0  66.0  43.0  39.0
# Cancelled     33.0  2.0  46.0   7.0  32.0

# %%
status = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1)
status = status[['Class Stat', 'Subject']]
status.columns = ['Status', 'Course Group']
status_pivot = status.pivot_table(index='Status', columns='Course Group', aggfunc=len)
status_pivot.fillna(0, inplace=True)
source = pd.DataFrame({'Course Group': ['ACL', 'ACR', 'CRT', 'ESL', 'LIN'], 'Cancelled': status_pivot.iloc[1]})
source['Cancelled'].sum()
# Out:
# 120.0

# %%
status = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1)
status = status[['Class Stat', 'Subject']]
status.columns = ['Status', 'Course Group']
status_pivot = status.pivot_table(index='Status', columns='Course Group', aggfunc=len)
status_pivot.fillna(0, inplace=True)
source = pd.DataFrame({'Course Group': ['ACL', 'ACR', 'CRT', 'ESL', 'LIN'], 'Cancelled': status_pivot.iloc[1]})

custom_color_scale = alt.Scale(
    domain=['ACL', 'ACR', 'CRT', 'ESL', 'LIN'],
    range=['#003264', '#ffbb00', '#00b945', '#f74133', '#00c1d4', '#ffa700'])

chart = alt.Chart(source).encode(
    theta=alt.Theta('Cancelled', stack=True), color=alt.Color('Course Group', scale=custom_color_scale, legend=None)
    )

title = alt.TitleParams(text='Section cancellations in Spring 2023', align='left', fontSize=16, fontWeight='bold', color='#003264')
chart = chart.properties(title=title)

chart = chart.mark_arc(outerRadius=120)
text = chart.mark_text(radius=140, size=13).encode(text='Course Group')

whole = chart + text
# Out:
# alt.LayerChart(...)

# %%
query = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1).fillna(0)
where = query[['Subject', 'Room']]
where_df = where[where['Room'] != 0]
where_df
# Out:
#     Subject   Room
# 4       ACL  OL-02
# 8       ACL  OL-03
# 9       ACL  OL-03
# 14      ACL  OL-03
# 21      ACL  OL-02
# ..      ...    ...
# 274     CRT  OF-01
# 276     CRT  OL-02
# 277     CRT  OL-02
# 278     LIN  OL-02
# 279     LIN  OL-02
#
# [159 rows x 2 columns]

# %%
query = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/Spring_23_query.csv', header=1).fillna(0)
where = query[['Subject', 'Room']]
where_df = where[where['Room'] != 0]

def where(df):
    where = df[['Subject', 'Room']]
    where.columns = ['Course', 'Room']
    where.loc[where['Room'].str.contains('OL-02'), 'Room'] = 'Online-async'
    where.loc[where['Room'].str.contains('OL-03'), 'Room'] = 'Online-sync'
    where.loc[where['Room'].str.contains('FH'), 'Room'] = 'In-person (Fitterman)'
    where.loc[where['Room'].str.contains('MC'), 'Room'] = 'In-person (Main Bldg)'
    where.loc[where['Room'].str.contains('MU'), 'Room'] = 'In-person (Murray)'
    where.loc[where['Room'].str.contains('CH'), 'Room']  = 'In-person (Inwood)'
    
    return where
where(where_df)
# Out:
#     Course          Room
# 4      ACL  Online-async
# 8      ACL   Online-sync
# 9      ACL   Online-sync
# 14     ACL   Online-sync
# 21     ACL  Online-async
# ..     ...           ...
# 274    CRT         OF-01
# 276    CRT  Online-async
# 277    CRT  Online-async
# 278    LIN  Online-async
# 279    LIN  Online-async
#
# [159 rows x 2 columns]

# %%
grouped = where(where_df).groupby(['Course', 'Room']).size().reset_index(name='Count')
grouped
# Out:
#    Course                   Room  Count
# 0     ACL           Online-async      9
# 1     ACL            Online-sync      3
# 2     CRT  In-person (Fitterman)     11
# 3     CRT     In-person (Inwood)      1
# 4     CRT  In-person (Main Bldg)      6
# 5     CRT     In-person (Murray)      2
# 6     CRT                  OF-01      5
# 7     CRT           Online-async     25
# 8     CRT            Online-sync     16
# 9     ESL  In-person (Main Bldg)     20
# 10    ESL     In-person (Murray)      3
# 11    ESL           Online-async     10
# 12    ESL            Online-sync     10
# 13    LIN  In-person (Fitterman)      4
# 14    LIN  In-person (Main Bldg)      4
# 15    LIN     In-person (Murray)      1
# 16    LIN           Online-async     22
# 17    LIN            Online-sync      7

# %%
chart = alt.Chart(grouped).mark_bar().encode(
    x='Count',
    y='Room',
    color='Course', order=alt.Order('Course', sort='ascending'))
chart
# Out:
# alt.Chart(...)

# %%
source = pd.DataFrame({'Course Group': ['ACL', 'ACR', 'CRT', 'ESL', 'LIN'], 'Cancelled': status_pivot.iloc[1]})

custom_color_scale = alt.Scale(
    domain=['ACL', 'ACR', 'CRT', 'ESL', 'LIN'],
    range=[ '#023e8a', '#48cae4', '#03045e', '#219ebc', '#8ecae6'])

chart = alt.Chart(source).mark_bar().encode(
    x=alt.X('Course Group', axis=alt.Axis(title='Course Group')),
    y=alt.Y('Cancelled', stack=True, axis=alt.Axis(title='Section cancellations')),
    color=alt.Color('Course Group', scale=custom_color_scale, legend=None)
)

title = alt.TitleParams(text='Section cancellations in Spring 2023 by course', align='left', fontSize=16, fontWeight='bold', color='#003264')
chart = chart.properties(title=title)

text = chart.mark_text(align='center', baseline='middle', dy=-5, size=13).encode(text='Cancelled')

whole = chart + text

whole
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
fall_23 = pd.read_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/FALL-2023-QUERY.csv', header=1).fillna(0)
fall_23
# Out:
#      Term Class Stat Subject Catalog# Section  Enrl Cap  Tot Enrl Days  \
# 0    1239     Active     ACL      120    050W        25        14    0
# 1    1239     Active     ACL      150    0501        25        24    0
# 2    1239     Active     ACL      150    051W        25        25    0
# 3    1239     Active     ACL      150    1000        30        23   Th
# 4    1239     Active     ACL      150    1101        27        22    W
# ..    ...        ...     ...      ...     ...       ...       ...  ...
# 218  1239  Cancelled     LIN      250    0506        25         0    0
# 219  1239  Cancelled     LIN      250    0507        25         0    0
# 220  1239  Cancelled     LIN      250    090W        25         0    0
# 221  1239  Cancelled     LIN     250H    900W         1         0    0
# 222  1239  Cancelled     LIN      250    A050        25         0    0
#
#     Mtg Start  Mtg End     Room                             Name
# ...

# %%
status = fall_23[['Class Stat', 'Subject']]
status.columns = ['Status', 'Course Group']
status_pivot = status.pivot_table(index='Status', columns='Course Group', aggfunc=len)
status_pivot.fillna(0, inplace=True)
status_pivot['Total'] = status_pivot.sum(axis=1)
status_pivot
# Out:
# Course Group  ACL  CRT  ESL  LIN  Total
# Status
# Active         19   50   31   36    136
# Cancelled      15   31    4   37     87

# %%
fall_23['Tot Enrl'].sum() - 1632
# Out:
# 425

# %%
len(fall_23['Name'].unique())
# Out:
# 47

# %%
import pandas as pd

class DataFramer:
    
    def __init__(self, name, df):
        self.name = name
        if 'Subject' in df.columns:
            df = df.rename(columns={'Subject': 'Course'})
        
        self.df = df
        self.df.replace(',', '', regex=True, inplace=True)
        self.df.replace('-', '', regex=True, inplace=True)
        
        # Check if '# Enrolled' exists in DataFrame columns before performing operations
        if '# Enrolled' in self.df.columns:
            self.df['# Enrolled'] = pd.to_numeric(self.df['# Enrolled'], errors='coerce')
        
    def get_name(self):
        return str(self.name)
    
    def get_df(self):
        return self.df
    
    def get_course(self, pattern):  
        filtered_df = self.df[self.df['Course'].str.contains(pattern)].groupby('Course').first().reset_index()
        return filtered_df

# %%
fall_2023 = DataFramer('2023f', fall_23)
fall_2023.get_course('CRT')
# Out:
#   Course  Term Class Stat Catalog# Section  Enrl Cap  Tot Enrl  Days  \
# 0    CRT  1239     Active      100    0500        25        12     0
#
#    Mtg Start  Mtg End  Room           Name
# 0          0        0  OL02  RobbElizabeth

# %%
spring_23 = pd.read_csv('datasets/spring_23.csv')
spring_23 = spring_23.rename(columns={'Unnamed: 0': 'Course'})
spring_2023 = DataFramer('2023s', spring_23)

# %%
# Reading the CSV file
fall_23 = pd.read_csv('datasets/fall_23.csv')

# Filtering only the columns you need
fall_23 = fall_23[['Course', '# Enrolled']]

aggregated_sum = fall_23.groupby('Course')['# Enrolled'].sum().reset_index()

# Counting the number of sections for each 'Course'
section_counts = fall_23.groupby('Course').size().reset_index(name='# of Sections')

# Merging the two DataFrames on 'Course'
fall_23 = pd.merge(aggregated_sum, section_counts, on='Course')

#fall_23.to_csv('/Users/eldarsarajlic/Desktop/Documents/Data_Projects/streamlit2/datasets/fall_23.csv', index=False)

fall_2023 = DataFramer('2023f', fall_23)
fall_2023.get_course('CRT')

fall_2023

# %%
print("Courses in fall_df:", fall_2023.get_course('LIN'))
print("Courses in spring_df:", spring_2023.get_course('LIN'))
# Out:
# Courses in fall_df:        Course  # Enrolled  # of Sections
# 0     LIN 100          89              1
# 1   LIN 100.6          14              1
# 2     LIN 101          47              1
# 3    LIN 101H           2              1
# 4     LIN 110           8              1
# 5     LIN 130           6              1
# 6     LIN 140          37              1
# 7     LIN 150         150              1
# 8     LIN 200           2              1
# 9     LIN 220           4              1
# 10    LIN 250         131              1
# 11   LIN 250H           1              1
# 12    LIN 300           6              1
# Courses in spring_df:      Course  # of Sections  # Enrolled
# 0   LIN 100              3          41
# 1   LIN 101              3          37
# 2   LIN 110              1          23
# 3   LIN 125              1           2
# 4   LIN 140              1           8
# 5   LIN 150              7         102
# 6  LIN 150H              1           3
# ...

# %%
common_courses = set(fall_2023.get_course('LIN')['Course']).intersection(set(spring_2023.get_course('LIN')['Course']))

fall_common = fall_2023.get_course('LIN')[fall_2023.get_course('LIN')['Course'].isin(common_courses)].reset_index(drop=True)
spring_common = spring_2023.get_course('LIN')[spring_2023.get_course('LIN')['Course'].isin(common_courses)].reset_index(drop=True)

comparison3 = pd.DataFrame({
    'Course': fall_common['Course'],
    'Fall 2023': fall_common['# Enrolled'],
    'Spring 2023': spring_common['# Enrolled']
})

comparison3
# Out:
#      Course  Fall 2023  Spring 2023
# 0   LIN 100         89           41
# 1   LIN 101         47           37
# 2   LIN 110          8           23
# 3   LIN 140         37            8
# 4   LIN 150        150          102
# 5   LIN 250        131          131
# 6  LIN 250H          1            3

# %%
def class_heatmap(df):
            times = df[df[['Days', 'Mtg Start']].notna().all(axis=1)]
            times.loc[:, 'Mtg Start'] = pd.to_datetime(times['Mtg Start'])
            times.loc[:, 'Mtg End'] = pd.to_datetime(times['Mtg End'])
            times.loc[:, 'Mtg Start'] = times['Mtg Start'].dt.strftime('%H:%M')
            times.loc[:, 'Mtg End'] = times['Mtg End'].dt.strftime('%H:%M')
            
            day_dict = {
            'M': 'Monday',
            'Tu': 'Tuesday',
            'MW': 'Monday, Wednesday',
            'MTh': 'Monday, Thursday',
            'TuTh': 'Tuesday, Thursday',
            'TuF': 'Tuesday, Friday',
            'MTuWTh': 'Monday, Tuesday, Wednesday, Thursday',
            'MWTh': 'Monday, Wednesday, Thursday',
            'MTuTh': 'Monday, Tuesday, Thursday',
            'TuW': 'Tuesday, Wednesday',
            'W': 'Wednesday',
            'Th': 'Thursday',
            'F': 'Friday',
            'Sa': 'Saturday',
            'Su': 'Sunday'}
            
            def convert_days(days):
                output_days = []
                for day in days.split(','):
                    if day.strip() in day_dict:
                        output_days.append(day_dict[day.strip()])
                return output_days
            
            times['Day'] = times['Days'].apply(convert_days).apply(', '.join)
            times = times.assign(Day=times.Day.str.split(","))
            times = times.explode('Day')
            
            day_df = times[['Mtg Start', 'Mtg End', 'Day']]
            
            stacked_days = pd.concat([day_df[day_df['Day']=='Monday'], 
                                day_df[day_df['Day']=='Tuesday'], 
                                day_df[day_df['Day']=='Wednesday'], 
                                day_df[day_df['Day']=='Thursday'],
                                day_df[day_df['Day']=='Friday'],
                                day_df[day_df['Day']=='Saturday'],
                                day_df[day_df['Day']=='Sunday']],
                                axis=0)
            stacked_days['Mtg Start'] = stacked_days['Mtg Start'].astype(str)
            stacked_days['Mtg End'] = stacked_days['Mtg End'].astype(str)

            df_pivot = stacked_days.pivot_table(index='Day', columns=['Mtg Start', 'Mtg End'], aggfunc=len, fill_value=0)

            df_pivot_long = df_pivot.reset_index().melt(id_vars=['Day'], var_name=['Mtg Start', 'Mtg End'], value_name='Count')
            
            ticks = list(df_pivot_long['Mtg Start'].unique())   
            chart = alt.Chart(df_pivot_long).mark_rect().encode(
                y=alt.Y('Mtg Start:N', title='Class start time', scale=alt.Scale(domain=(ticks))),
                x=alt.X('Day:O', sort=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']),
                color=alt.Color('Count:Q', title='# of class meetings', scale=alt.Scale(scheme='blues'), legend=None),
                #tooltip=[alt.Tooltip('Count:Q', title='# of class meetings')]
            ).properties(
                width=400,
                height=400
            )
            
            title = alt.TitleParams(text='Class meetings time of the day in Fall 2023', align='left', fontSize=16, fontWeight='bold', color='#003264')
            chart = chart.properties(title=title)
            chart = chart.configure_axis(labelAngle=-0, title='')

          
            st.altair_chart(chart, use_container_width=True) 
            
        query_23 = pd.read_csv('datasets/FALL-2023-QUERY.csv', header=1)
        
        class_heatmap(query_23)

# %%
stacked_days['Mtg Start'] = stacked_days['Mtg Start'].astype(str)
stacked_days['Mtg End'] = stacked_days['Mtg End'].astype(str)

df_pivot = stacked_days.pivot_table(index='Day', columns=['Mtg Start', 'Mtg End'], aggfunc=len, fill_value=0)

df_pivot_long = df_pivot.reset_index().melt(id_vars=['Day'], var_name=['Mtg Start', 'Mtg End'], value_name='Count')


ticks = pd.to_datetime(df_pivot_long['Mtg Start']).dt.strftime('%H:%M').unique().tolist()

ticks2 = list(df_pivot_long['Mtg Start'].unique())
